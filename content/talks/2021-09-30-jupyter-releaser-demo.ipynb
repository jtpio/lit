// %% [markdown]
// <br><br><br><br><br><br><br><br><br>

// %% [markdown]
// <h1 style="text-align: center">Jupyter Releaser 🚀 </h1>
// <h2 style="text-align: center">Demo - 2021-09-30</h2>
// <h2 style="text-align: center"><a href="https://github.com/jupyter-server/jupyter_releaser">https://github.com/jupyter-server/jupyter_releaser</a></h2>

// %% [markdown]
// <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>

// %% [markdown]
// ## Why do we need it?
//
//   - Complex release process for JupyterLab
//   - More and more projects to maintain: https://pypi.org/manage/projects/
//   - **Ensure best practices**:
//     - Documented, transparent releases:
//     - Assets are built on CI, not on a local machine
//     - Process is streamlined, less error-proned
//     - Full release logs are accessible: https://github.com/jtpio/jupyter_releaser/runs/3753501817?check_suite_focus=true
//   - Motivation: https://jupyter-releaser.readthedocs.io/en/latest/background/theory.html#motivation

// %% [markdown]
// <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>

// %% [markdown]
// ## Which repos are using it?
//
//   - https://github.com/jupyterlab/jupyterlab
//   - https://github.com/jupyterlab/retrolab
//   - https://github.com/ipython/ipykernel
//   - https://github.com/jupyter/jupyter_server
//   - https://github.com/jupyter/jupyter_client
//   - https://github.com/jupyterlite/jupyterlite
//   - https://github.com/jupyterlite/p5-kernel
//   - https://github.com/voila-dashboards/voila
//   - https://github.com/jupyterlab-contrib/jupyterlab-cell-flash
//   - https://github.com/jupyterlab-contrib/jupyterlab-plugin-graph
//   - https://github.com/QuantStack/jupyterlab-js-logs
//   - ... and more
//
//  Can also be used to release other Python or npm packages

// %% [markdown]
// <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>

// %% [markdown]
// ## How to adopt the Releaser?
//   - Add the Releaser config: https://jupyter-releaser.readthedocs.io/en/latest/how_to_guides/convert_repo.html
//   - Example PR: https://github.com/QuantStack/jupyterlab-snippets/pull/38
//   - Add `npm` and `PyPI` tokens:
//     - PyPI: https://pypi.org/manage/account/token/
//     - npm: https://www.npmjs.com/settings/jtpio/tokens
//     - GitHub Secrets: https://github.com/jtpio/jupyter_releaser/settings/secrets/actions
//   - `PYPI_TOKEN_MAP`:
//
// ```bash
// QuantStack/jupyterlab-snippets,pypi-AgEIcHlwaS5vcmcCJ...
// jupyterlab/retrolab,pypi-AgEIcHlwaS5vcmcCJ...
// ...
// ```

// %% [markdown]
// <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>

// %% [markdown]
// ## Versioning
//
// - Simple (JupyterLab Extension, Jupyter Widgets):
//   - https://github.com/QuantStack/jupyterlab-snippets/blob/928cb72793a42d5f5ae3bed4de103c4640d9fe59/package.json#L3
//   - https://github.com/QuantStack/jupyterlab-snippets/blob/928cb72793a42d5f5ae3bed4de103c4640d9fe59/jupyterlab_snippets/_version.py
//
// - More complex:
//   - JupyterLab: https://github.com/jupyterlab/jupyterlab/blob/master/buildutils/src/bumpversion.ts
//   - Voila: https://github.com/voila-dashboards/voila/blob/main/scripts/bump-version.py
//   - Custom `version-cmd`: https://github.com/voila-dashboards/voila/blob/641837632266e5363565cf1c736d8369ca7470a1/pyproject.toml#L27-L28
//   - JupyterLite: custom Python build (`doit` tasks)
//
// ![image.png](attachment:af2d4ff1-33b8-47ca-9df0-758dbcaf6f00.png)
//
// ## Hooks
//
// - Run arbitraty commands `before` / `after` bumping the version, building Python / npm, ...
// - Example with JupyterLab: https://github.com/jupyterlab/jupyterlab/blob/53e2b5823a943798a6438dae2efa21c875aa0f83/pyproject.toml#L39-L43
//
// ![image.png](attachment:f13a1bed-726a-45c2-b1de-6d3523be281a.png)

// %% [markdown]
// <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>

// %% [markdown]
// ## Changelog Generation
//
// - Using `github-activity`: https://github.com/executablebooks/github-activity
// - Use GitHub labels: `enhancement`, `maintenance`, `bug`...
//
// ![image.png](attachment:2261f7ca-782b-4ffb-9baa-41dccfd58a6a.png)
//
// ![image.png](attachment:6c22bcd0-4133-4b9b-baf9-e2572e6d6af5.png)

// %% [markdown]
// <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>

// %% [markdown]
// ## Workflow
//
//
// - Example with https://github.com/QuantStack/jupyterlab-snippets/pull/39
// - Draft Changelog
//   - Go to: https://github.com/jtpio/jupyter_releaser/actions/workflows/draft-changelog.yml
//   - Specify the new version spec
// - Full Release
//   - Go to: https://github.com/jtpio/jupyter_releaser/actions/workflows/full-release.yml
//   - Use the parameters from the Changelog PR
// - That's it! 🚀
//   - GitHub Release: https://github.com/QuantStack/jupyterlab-snippets/releases
//   - `PyPI`: https://pypi.org/project/jupyterlab-snippets
//   - `npm`: https://www.npmjs.com/package/jupyterlab-snippets
//
// ## Other Examples
//
// - Assets are uploaded to the GitHub Release: https://github.com/voila-dashboards/voila/releases/tag/v0.2.14
//
// ![image.png](attachment:d5cea351-ea05-4db1-85f3-9ab02d113dcf.png)

// %% [markdown]
// <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>

// %% [markdown]
// ## Extras (if there is time)
//
// - Brief look at the code: https://github.com/jupyter-server/jupyter_releaser/tree/master/jupyter_releaser
